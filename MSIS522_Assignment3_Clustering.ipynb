# %% [markdown]
# <a href="https://colab.research.google.com/github/vbang247/python/blob/main/MSIS522_Assignment3_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Problem 1: Segment Customers

# %% [markdown]
# The problem that we are going to solve in this assignment is to segment customers into different groups based on their shopping trends.

# %%
# import packages
# %matplotlib inline
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
pd.set_option('display.max_colwidth',0)

# %% [markdown]
# ### Load data
#
# Our dataset has five columns: CustomerID, Genre, Age, Annual Income, and Spending Score. To view the results in two-dimensional feature space, we will retain only two of these five columns. We can remove CustomerID column, Genre, and Age column. We will retain the Annual Income (in thousands of dollars) and Spending Score (1-100) columns. The Spending Score column signifies how often a person spends money in a mall on a scale of 1 to 100 with 100 being the highest spender.

# %%
# load the data
shopping_data = pd.read_csv('https://raw.githubusercontent.com/zariable/data/master/shopping_data.csv')
shopping_data.rename(
    columns={
        'CustomerID': 'customer_id',
        'Genre': 'genre',
        'Age': 'age',
        'Annual Income (k$)': 'annual_income',
        'Spending Score (1-100)': 'spending_score'
    },
    inplace=True
)
display(shopping_data.head())
X = np.array(shopping_data[['annual_income', 'spending_score']])

# TODO: retain only anual_income and spending_score for clustering
# Out:
#    customer_id   genre  age  annual_income  spending_score
# 0  1            Male    19   15             39
# 1  2            Male    21   15             81
# 2  3            Female  20   16             6
# 3  4            Female  23   16             77
# 4  5            Female  31   17             40

# %%
X = shopping_data[['annual_income','spending_score']].to_numpy()

# %% [markdown]
# ### Hierarchical Clustering
# First, we will apply hierarchical clustering and use dendrogram to help find the number of clusters within the data.
#
# **TODO: Use dendrogram to plot hierarchical clustering and find the number of clusters that makes sense.**

# %%
from traitlets.traitlets import link
from sklearn.cluster import AgglomerativeClustering

import scipy.cluster.hierarchy as shc

# TODO
dend = shc.dendrogram(shc.linkage(X, method='ward'))

# %% [markdown]
# **TODO: Apply hierarchical clustering based on the number of clusters you pick from the dendrogram, and visualize the results using scatterplot.**

# %%
from traitlets.traitlets import link
from sklearn.cluster import AgglomerativeClustering

# TODO
cluster = AgglomerativeClustering(n_clusters=4, linkage="ward")
y_agglomerative = cluster.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=y_agglomerative)

# %% [markdown]
# ### K-means Clustering
# Then, we will apply k-means to the same data and visualize the results.
#
# **TODO: Vary the number of K from 2 to 10 and plot the Sum of Squared Error (SSE) as K increases and pick up the value of K that makes sense.**

# %%
# TODO
from sklearn.cluster import KMeans
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(shopping_data[['annual_income', 'spending_score']])
    distortions.append(kmeanModel.inertia_)
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# **TODO: Cluster the data using K-means based on the pre-defined value of K from the previous step and and visualize the results using scatterplot. **

# %%
# TODO
kModel = KMeans(n_clusters=5)
kModel.fit(shopping_data[['annual_income', 'spending_score']])
y_agglomerative = kModel.predict(shopping_data[['annual_income', 'spending_score']])
plt.scatter(shopping_data['annual_income'], shopping_data['spending_score'], c=y_agglomerative)

# %% [markdown]
# ## Problem 2: Clustering (Manually)

# %% [markdown]
# For the following dataset, perform the clustering “by hand”:
#
# 17 28 50 60 80 89 150 167 171 189
# 1. 	Use the K-means algorithm with K= 3 to cluster the data
# 2. 	Use hierarchical agglomerative clustering with single linkage to cluster the data
# 3. 	Use hierarchical agglomerative clustering with complete linkage to cluster the data
# 4. 	For K-means What will the final clusters be after 3 iterations if k=3 and the initial centers are 150, 171 and 189

# %% [markdown]
# **1. Use the K-means algorithm with K= 3 to cluster the data**

# %%
# import matplotlib.image as mpimg
# img = mpimg.imread('2_1.jpeg')
# imgplot = plt.imshow(img)
# plt.show()
from IPython.display import display, Image
display(Image(filename='2_1.jpeg',width=500))

# %% [markdown]
# **2. Use hierarchical agglomerative clustering with single linkage to cluster the data**

# %%
display(Image(filename='2_2.jpeg',width=500, height=500))

# %% [markdown]
# **3. Use hierarchical agglomerative clustering with complete linkage to cluster the data**

# %%
display(Image(filename='2_3.jpeg',width=500, height=500))

# %% [markdown]
#  **4. For K-means What will the final clusters be after 3 iterations if k=3 and the initial centers are 150, 171 and 189**

# %%
display(Image(filename='2_4.jpeg',width=500, height=500))

# %% [markdown]
# ## Bonus points
# Use the dataset of accepted papers at the AAAI 2014 conference to find clusters of papers using K-Means. You can use paper title or abstract to build your features using [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model).
#
# 1. Vary the number of K from 2 to 6 and show if the results vary and assess the clusters obtained.
#
# 2. Make a case regarding which clusters ‘make sense’ e.g., is there a cluster were papers on reinforcement learning are together vs. another cluster which has papers on deep learning.

# %% [markdown]
# # **I have listed below centers for each cluster as well as titles belonging to that cluster while varying k from 2 to 6.**

# %%
# Load the Relevant libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import sklearn as sk

# URL for the AAAI (UW Repository)
aaai_data = pd.read_csv("https://raw.githubusercontent.com/zariable/data/master/AAAI2014AcceptedPapers.csv")

# TODO
# aaai_data.head()

# %%
from pandas.core.frame import DataFrame
# true_k = 6
# model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
# model.fit(X)
# print("Top terms per cluster:")
# order_centroids = model.cluster_centers_.argsort()[:, ::-1]
# terms = vectorizer.get_feature_names()
# big_l = {}
for k in range(2,7):
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(aaai_data['title'])
    model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
    model.fit(X)
    # print("Top terms per cluster:")
    order_centroids = model.cluster_centers_.argsort()[:, ::-1]
    # print(order_centroids)
    # print(k)
    terms = vectorizer.get_feature_names()
    big_l = {}
    for i in range(k):
      short_l = []
      for ind in order_centroids[i, :10]:
          short_l.append(terms[ind])
      big_l["Cluster" + str(i+1)] = short_l
    df = pd.DataFrame(big_l)
    clusters = df.columns.tolist()
    print(df.head())
    print("\n")
    for c in clusters:
      print("Titles in "+c)
      for j in df[c]:
        new_t = aaai_data[aaai_data['title'].str.contains(j)]['title'].tolist()
        if len(new_t) > 0:
          print(new_t) 
      print("\n")
# Out:
#    Cluster1  Cluster2
# 0  social    learning
# 1  search    based
# 2  using     multi
# 3  linear    model
# 4  networks  sparse
#
#
# Titles in Cluster1
# ['Extracting Keyphrases from Research Papers using Citation Networks']
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
# ['Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests', 'Similarity-preserving binary signature for linear subspace']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Lifetime Lexical Variation in Social Media', 'Adaptive Multi-Compositionality for Recursive Neural Models with Applications to Sentiment Analysis', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'SenticNet 3: A Common and Common-Sense Knowledge Base for Cognition-Driven Sentiment Analysis', 'Acquiring Commonsense Knowledge for Sentiment Analysis through Human Computation', 'Anytime Active Learning', 'Machine Translation with Real-time Web Search', 'Mixing-time Regularized Policy Gradient']
# ['Intelligent System for Urban Emergency Management During Large-scale Disaster', 'Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests']
#
#
# Titles in Cluster2
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Detecting information-dense texts in multiple news domains', 'locality preserving projection via multi-objective learning for domain adaptation', 'Strategyproof exchange with multiple private endowments']
# ['SUIT: A Supervised User-Item based Topic model for Sentiment Analysis']
# ['Scalable sparse covariance estimation via self-concordance']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['TopicMF: Simultaneously Exploiting Ratings and Reviews for Recommendation', 'Preference Elicitation and Interview Minimization in Stable Matchings', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'Intra-view and Inter-view Supervised Correlation Analysis for Multi-view Feature Learning', 'Uncorrelated Multi-view Fisher Discrimination Dictionary Learning For Recognition', 'Prediction of Helpful Reviews using Emotions Extraction']
#
#
#    Cluster1  Cluster2  Cluster3
# 0  games     learning  based
# 1  using     multi     planning
# 2  problems  sparse    search
# 3  large     social    multiple
# 4  scale     models    model
#
#
# Titles in Cluster1
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Intelligent System for Urban Emergency Management During Large-scale Disaster', 'Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning', 'A spatio-temporal pattern mining algorithm to identify objects in a continuous field: A global oceanography perspective']
#
#
# Titles in Cluster2
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Detecting information-dense texts in multiple news domains', 'locality preserving projection via multi-objective learning for domain adaptation', 'Strategyproof exchange with multiple private endowments']
# ['Scalable sparse covariance estimation via self-concordance']
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
#
#
# Titles in Cluster3
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Extracting Keyphrases from Research Papers using Citation Networks']
# ['Detecting information-dense texts in multiple news domains', 'Strategyproof exchange with multiple private endowments']
# ['SUIT: A Supervised User-Item based Topic model for Sentiment Analysis']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Efficient buyer groups for prediction-of-use electricity tariffs']
# ['Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Detecting information-dense texts in multiple news domains', 'locality preserving projection via multi-objective learning for domain adaptation']
#
#
#   Cluster1        Cluster2    Cluster3        Cluster4
# 0  search   using           model       learning
# 1  social   rules           stochastic  based
# 2  linear   texts           checking    multi
# 3  games    networks        based       data
# 4  large    classification  privacy     classification
#
#
# Titles in Cluster1
# ['Extracting Keyphrases from Research Papers using Citation Networks']
# ['Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests', 'Similarity-preserving binary signature for linear subspace']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Lifetime Lexical Variation in Social Media', 'Adaptive Multi-Compositionality for Recursive Neural Models with Applications to Sentiment Analysis', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'SenticNet 3: A Common and Common-Sense Knowledge Base for Cognition-Driven Sentiment Analysis', 'Acquiring Commonsense Knowledge for Sentiment Analysis through Human Computation', 'Anytime Active Learning', 'Machine Translation with Real-time Web Search', 'Mixing-time Regularized Policy Gradient']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Multiagent Metareasoning Through Organizational Design']
#
#
# Titles in Cluster2
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
# ['Detecting information-dense texts in multiple news domains']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Detecting information-dense texts in multiple news domains']
#
#
# Titles in Cluster3
# ['SUIT: A Supervised User-Item based Topic model for Sentiment Analysis']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['A Strategy-Proof Online Auction with Time Discounting Values']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Proximal Iteratively Reweighted Algorithm with Multiple Splitting for Nonconvex Sparsity Optimization']
#
#
# Titles in Cluster4
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Detecting information-dense texts in multiple news domains', 'locality preserving projection via multi-objective learning for domain adaptation', 'Strategyproof exchange with multiple private endowments']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Scalable sparse covariance estimation via self-concordance']
# ['TopicMF: Simultaneously Exploiting Ratings and Reviews for Recommendation', 'Preference Elicitation and Interview Minimization in Stable Matchings', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'Intra-view and Inter-view Supervised Correlation Analysis for Multi-view Feature Learning', 'Uncorrelated Multi-view Fisher Discrimination Dictionary Learning For Recognition', 'Prediction of Helpful Reviews using Emotions Extraction']
#
#
#    Cluster1     Cluster2 Cluster3        Cluster4  Cluster5
# 0  based     using        rank     social          learning
# 1  planning  constraints  low      information     sparse
# 2  model     embedding    rules    recommendation  multi
# 3  search    multiple     scoring  networks        transfer
# 4  time      based        voting   choice          instance
#
#
# Titles in Cluster1
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['SUIT: A Supervised User-Item based Topic model for Sentiment Analysis']
# ['Extracting Keyphrases from Research Papers using Citation Networks']
# ['Lifetime Lexical Variation in Social Media', 'Adaptive Multi-Compositionality for Recursive Neural Models with Applications to Sentiment Analysis', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'SenticNet 3: A Common and Common-Sense Knowledge Base for Cognition-Driven Sentiment Analysis', 'Acquiring Commonsense Knowledge for Sentiment Analysis through Human Computation', 'Anytime Active Learning', 'Machine Translation with Real-time Web Search', 'Mixing-time Regularized Policy Gradient']
# ['Multiagent Metareasoning Through Organizational Design']
# ['Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests', 'Similarity-preserving binary signature for linear subspace']
#
#
# Titles in Cluster2
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
# ['Convex Co-embedding']
# ['Detecting information-dense texts in multiple news domains', 'Strategyproof exchange with multiple private endowments']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Extracting Keyphrases from Research Papers using Citation Networks']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'A spatio-temporal pattern mining algorithm to identify objects in a continuous field: A global oceanography perspective', 'Combining Heterogenous Social and Geographical Information for Event Recommendation', 'Mapping Users Across Networks by Manifold Alignment on Hypergraph']
#
#
# Titles in Cluster3
# ['Locality-constrained Low-rank Coding for Image Classification']
# ['Robust Visual Robot Localization Across Seasons using Network Flows']
# ['Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Predicting Postoperative Atrial Fibrillation from Independent ECG Components']
#
#
# Titles in Cluster4
# ['Detecting information-dense texts in multiple news domains']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Efficient buyer groups for prediction-of-use electricity tariffs']
# ['Context-aware Collaborative Topic Regression with Social Matrix Factorization for Recommender Systems', 'Role-aware Conformity Modeling and Analysis in Social Networks']
#
#
# Titles in Cluster5
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Scalable sparse covariance estimation via self-concordance']
# ['Detecting information-dense texts in multiple news domains', 'locality preserving projection via multi-objective learning for domain adaptation', 'Strategyproof exchange with multiple private endowments']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning', 'Learning Goal-Oriented Hierarchical Tasks from Situated Interactive Instruction', 'Coactive Learning for Locally Optimal Problem Solving']
# ['Learning Parametric Models for Social Infectivity in Multi-dimensional Hawkes Processes', 'Automatic Construction and Natural-Language Description of Nonparametric Regression Models', 'Relational One-Class Classification: A Non-Parametric Approach']
#
#
#       Cluster1   Cluster2  Cluster3  Cluster4  Cluster5    Cluster6
# 0  using        non        search    bayesian  learning  model
# 1  social       manifold   large     network   multi     stochastic
# 2  based        method     problems  best      view      checking
# 3  information  structure  scale     learning  instance  based
# 4  games        local      time      classes   transfer  privacy
#
#
# Titles in Cluster1
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Detecting information-dense texts in multiple news domains']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests', 'Similarity-preserving binary signature for linear subspace']
#
#
# Titles in Cluster2
# ['Decentralized Stochastic Planning with Anonymity in Interactions']
# ['Managing Change in Graph-structured Data Using Description Logics']
# ['locality preserving projection via multi-objective learning for domain adaptation']
# ['A Local Non-negative Pursuit Method for Intrinsic Manifold Structure Preservation', 'Robust Non-negative Dictionary Learning']
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
#
#
# Titles in Cluster3
# ['Extracting Keyphrases from Research Papers using Citation Networks']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Intelligent System for Urban Emergency Management During Large-scale Disaster', 'Non-linear Label Ranking for Large-scale Prediction of Long-Term User Interests']
# ['Lifetime Lexical Variation in Social Media', 'Adaptive Multi-Compositionality for Recursive Neural Models with Applications to Sentiment Analysis', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'SenticNet 3: A Common and Common-Sense Knowledge Base for Cognition-Driven Sentiment Analysis', 'Acquiring Commonsense Knowledge for Sentiment Analysis through Human Computation', 'Anytime Active Learning', 'Machine Translation with Real-time Web Search', 'Mixing-time Regularized Policy Gradient']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
#
#
# Titles in Cluster4
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Finding the k-best Equivalence Classes of Bayesian Network Structures for Model Averaging']
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Solving Uncertain MDPs by Reusing State Information and Plans', 'Robust Visual Robot Localization Across Seasons using Network Flows', 'Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning', 'Extracting Keyphrases from Research Papers using Citation Networks', 'Generating Content for Scenario-Based Serious-Games using CrowdSourcing', 'Lifting Relational MAP-LP Relaxations using Permutation Constraint Graphs', 'Structured Possibilistic Planning using Decision Diagrams', 'Programming by Example using Least General Generalizations', 'Maximum Satisfiability using core-guided MaxSAT Resolution', 'Effective Management of Electric Vehicle Storage using Smart Charging', 'GP-Localize: Persistent Mobile Robot Localization using Online Sparse Gaussian Process Observation Model', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'User Intent Identification from Online Discussions using a Joint Aspect-Action Topic Model', 'Monte Carlo Filtering using Kernel Embedding of Distributions', 'Joule Counting Correction for Electric Vehicles using Artificial Neural Nets', 'Prediction of Helpful Reviews using Emotions Extraction']
#
#
# Titles in Cluster5
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Detecting information-dense texts in multiple news domains', 'locality preserving projection via multi-objective learning for domain adaptation', 'Strategyproof exchange with multiple private endowments']
# ['TopicMF: Simultaneously Exploiting Ratings and Reviews for Recommendation', 'Preference Elicitation and Interview Minimization in Stable Matchings', 'Pre-trained Multi-view Word Embedding using Two-side Neural Network', 'Intra-view and Inter-view Supervised Correlation Analysis for Multi-view Feature Learning', 'Uncorrelated Multi-view Fisher Discrimination Dictionary Learning For Recognition', 'Prediction of Helpful Reviews using Emotions Extraction']
# ['Scalable sparse covariance estimation via self-concordance']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['Learning Parametric Models for Social Infectivity in Multi-dimensional Hawkes Processes', 'Automatic Construction and Natural-Language Description of Nonparametric Regression Models', 'Relational One-Class Classification: A Non-Parametric Approach']
#
#
# Titles in Cluster6
# ['SUIT: A Supervised User-Item based Topic model for Sentiment Analysis']
# ['Fast consistency checking of very large real-world RCC-8 constraint  networks using graph partitioning']
# ['Type-based Exploration  for Satisficing Planning with Multiple Search Queues', 'Quality-based Learning for Web Data Classification', 'SUIT: A Supervised User-Item based Topic model for Sentiment Analysis', 'Deep Modeling of Group Preferences for Group-based Recommendation', 'Instance-based Domain Adaptation in NLP via In-target-domain Logistic Approximation', 'Adaptive Singleton-based Consistencies', 'Schedule-based Robotic Search for Multiple Residents in a Retirement Home Environment', 'Improving Domain-independent Cloud-based Speech Recognition with Domain-dependent Phonetic Post-processing', 'Modeling Subjective Experience-based Learning under Uncertainty and Frames', 'Regret-based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty', 'Novel Density-based Clustering Algorithms for Uncertain Data', 'Data Quality in Ontology-based Data Access: The Case of Consistency', 'Point-based POMDP solving with factored value function approximation']
# ['A Strategy-Proof Online Auction with Time Discounting Values']
# ['Modeling and mining spatiotemporal patterns of infection risk from heterogeneous data for active surveillance planning']
# ['Evolutionary dynamics of learning algorithms over the sequence form', 'locality preserving projection via multi-objective learning for domain adaptation', 'Non-convex feature learning via $\\ell_{p,\\infty}$ operator']
# ['Proximal Iteratively Reweighted Algorithm with Multiple Splitting for Nonconvex Sparsity Optimization']

# %%
# for x in clusters:
#   print("Titles in "+x)
#   for j in df[x]:
#     new_t = aaai_data[aaai_data['title'].str.contains(j)]['title'].tolist()
#     if len(new_t) > 0:
#       print(new_t) 
#   print("\n")
